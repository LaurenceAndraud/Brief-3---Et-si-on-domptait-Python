# %%
import pandas as pd

df_google_ap_1 = pd.read_csv("Desktop/googleplaystore_1.csv", sep=";")
print(df_google_ap_1)
# Out:
#                                                    App        Category Rating  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                  Coloring book moana  ART_AND_DESIGN    3.9
# 2                                Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 3                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                           Paper flowers instructions  ART_AND_DESIGN    4.4
# ..                                                 ...             ...    ...
# 495                          BBWCupid - BBW Dating App          DATING    3.5
# 496                          ChatVideo Meet new people          DATING    4.2
# 497  Black White Interracial Dating - Interracial M...          DATING    4.1
# 498             FlirtChat - ♥Free Dating/Flirting App♥          DATING    4.3
# 499                                     OkCupid Dating          DATING    4.1
#
# ...

# %%
# avoir un résumé de notre tableau, et visualiser le nbre d'entrées et le nom des colonnes
df_google_ap_1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 13 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   App             500 non-null    object
#  1   Category        500 non-null    object
#  2   Rating          488 non-null    object
#  3   Reviews         500 non-null    float64
#  4   Size            500 non-null    object
#  5   Installs        500 non-null    object
#  6   Type            500 non-null    object
#  7   Price           500 non-null    object
#  8   Content Rating  500 non-null    object
#  9   Genres          500 non-null    object
#  10  Last Updated    492 non-null    object
#  11  Current Ver     491 non-null    object
#  12  Android Ver     492 non-null    object
# dtypes: float64(1), object(12)
# memory usage: 50.9+ KB

# %%
df_google_ap_1.append(df_google_ap_1)
# Out:
# C:\Users\utilisateur\AppData\Local\Temp\ipykernel_16420\1168123918.py:1: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_google_ap_1.append(df_google_ap_1)
#                                                    App        Category Rating  \
# 0       Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                                  Coloring book moana  ART_AND_DESIGN    3.9
# 2                                Sketch - Draw & Paint  ART_AND_DESIGN    4.5
# 3                Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                           Paper flowers instructions  ART_AND_DESIGN    4.4
# ..                                                 ...             ...    ...
# 495                          BBWCupid - BBW Dating App          DATING    3.5
# 496                          ChatVideo Meet new people          DATING    4.2
# ...

# %%
df_google_ap_1[df_google_ap_1['Installs']>10000]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [18], in <cell line: 1>()
# ----> 1 df_google_ap_1[df_google_ap_1['Installs']>10000]
#
# File ~\anaconda3\lib\site-packages\pandas\core\ops\common.py:70, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      66             return NotImplemented
#      68 other = item_from_zerodim(other)
# ---> 70 return method(self, other)
#
# File ~\anaconda3\lib\site-packages\pandas\core\arraylike.py:56, in OpsMixin.__gt__(self, other)
#      54 @unpack_zerodim_and_defer("__gt__")
#      55 def __gt__(self, other):
# ---> 56     return self._cmp_method(other, operator.gt)
#
# File ~\anaconda3\lib\site-packages\pandas\core\series.py:5623, in Series._cmp_method(self, other, op)
#    5620 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
#    5622 with np.errstate(all="ignore"):
# ...

# %%
# utiliser la fonction max() pour saisir la valeur maximale
df_google_ap_1['Reviews'].max()
# Out:
# 69119316.0

# %%
#retrouver l'indice de la ligne correspondant à la valeur max avec la fonction idxmax
df_google_ap_1['Reviews'].idxmax()
# Out:
# 314

# %%
# retrouver le nom de l'application en insérant le numéro de ligne
df_google_ap_1.iloc[314,:]['App']
# Out:
# 'WhatsApp Messenger'

# %%
# vérifier mon précédent résultat
df_google_ap_1[df_google_ap_1['Reviews'] == df_google_ap_1['Reviews'].max()]
# Out:
#                     App       Category Rating     Reviews                Size  \
# 314  WhatsApp Messenger  COMMUNICATION    4.4  69119316.0  Varies with device
# 359  WhatsApp Messenger  COMMUNICATION    4.4  69119316.0  Varies with device
#
#            Installs  Type Price Content Rating         Genres    Last Updated  \
# 314  1,000,000,000+  Free     0       Everyone  Communication  August 3, 2018
# 359  1,000,000,000+  Free     0       Everyone  Communication  August 3, 2018
#
#             Current Ver         Android Ver
# 314  Varies with device  Varies with device
# 359  Varies with device  Varies with device

# %%
# utiliser la commande iloc pour sélectionner la valeur se situant dans la colonne et ligne donnée
df_google_ap_1.iloc[314,:]['Rating']
# Out:
# '4.4'

# %%
df_google_ap_1.iloc[[3,16],[2,5,6]]
# Out:
#    Rating  Installs  Type
# 3     4.3  100,000+  Free
# 16    4.5   10,000+  Free

# %%
df_google_ap_1.iloc[:,8].value_counts('Everyone')
# Out:
# Everyone           0.782
# Mature 17+         0.122
# Teen               0.070
# Everyone 10+       0.016
# 0                  0.008
# Adults only 18+    0.002
# Name: Content Rating, dtype: float64

# %%
df_google_ap_1[df_google_ap_1["Content Rating"] == "Everyone"]
# Out:
#                                                 App        Category Rating  \
# 0    Photo Editor & Candy Camera & Grid & ScrapBook  ART_AND_DESIGN    4.1
# 1                               Coloring book moana  ART_AND_DESIGN    3.9
# 3             Pixel Draw - Number Art Coloring Book  ART_AND_DESIGN    4.3
# 4                        Paper flowers instructions  ART_AND_DESIGN    4.4
# 5           Smoke Effect Photo Maker - Smoke Editor  ART_AND_DESIGN    3.8
# ..                                              ...             ...    ...
# 444                    Glide - Video Chat Messenger   COMMUNICATION    4.3
# 445                    Talkray - Free Calls & Texts   COMMUNICATION    4.2
# 446                     LINE: Free Calls & Messages   COMMUNICATION    4.2
# 447                    KakaoTalk: Free Calls & Text   COMMUNICATION    4.3
# 448                                      Calculator          DATING    2.6
#
# ...

# %%
df_google_ap_1.groupby(by='Category')
